# %% [markdown]
# Complete AI Agent orchestration with langgraph

# %%
import os
from dotenv import load_dotenv

load_dotenv()

GOOGLE_API_KEY = os.getenv("GOOGLE_API_KEY")

# %% [markdown]
# Triage chain

# %%
from pydantic import BaseModel, Field
from typing import Literal

class TriageOut(BaseModel):
    decision: Literal["SELF_RESOLVE","REQUEST_INFO","OPEN_TICKET"]
    urgency: Literal["LOW", "MEDIUM", "HIGH"]
    missing_fields: list[str] = Field(default_factory=list)

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    temperature=0,
    api_key=GOOGLE_API_KEY
)

# %%
triage_Prompt = ("""
                    # Role
                  You are a Service Desk agent responsible for triaging requests related to internal policies at the company "Carraro Desenvolvimento".

                  # Task
                  Given a user's message, you must return ONLY a JSON object with the following structure:
                  {
                    "decision": "SELF_RESOLVE" | "REQUEST_INFO" | "OPEN_TICKET",
                    "urgency": "LOW" | "MEDIUM" | "HIGH",
                    "missing_fields": ["..."]
                  }

                  # Decision Rules
                  - **SELF_RESOLVE**: Use this for clear questions about rules or procedures described in the policies (e.g., "Can I get reimbursed for my home office internet?", "How does the meal policy for work travel function?").
                  - **REQUEST_INFO**: Use this for vague messages that lack the necessary information to identify the topic or context (e.g., "I need help with a policy," "I have a general question.").
                    - When using this decision, you must populate the "missing_fields" array with the specific information that needs clarification (e.g., "policy_name", "problem_description").
                  - **OPEN_TICKET**: Use this for requests that require an exception, release, approval, or special access, or when the user explicitly asks to open a ticket (e.g., "I want an exception to work 5 days remotely," "I am requesting clearance for external attachments," "Please open a ticket with HR for me.").

                  # Urgency Rules
                  - **HIGH**: The user reports an issue that completely prevents them from working, or they mention a security risk, legal issue, or data loss (e.g., "I can't access the system to do my job," "I received a phishing email and clicked the link").
                  - **MEDIUM**: The user has a problem that hinders their work but doesn't block it, or they have an approaching deadline (e.g., "I need approval for a trip next week").
                  - **LOW**: General questions, doubts about policies, or requests that do not have an immediate deadline (e.g., "How does the vacation policy work?", "I have a question about reimbursement").

                  # Final Instruction
                  Analyze the user's message and determine the most appropriate action ("decision") and "urgency" based on the rules defined above.
                  """)

# %%
from langchain_core.messages import SystemMessage, HumanMessage

triage_chain = llm.with_structured_output(TriageOut)

def triage(message:str) ->dict:
    output: TriageOut = triage_chain.invoke([
        SystemMessage(content=triage_Prompt),
        HumanMessage(content=message)
    ])
    return output.model_dump()

# %% [markdown]
# RAG chain

# %%
from pathlib import Path
from langchain_community.document_loaders import PyMuPDFLoader

docs = []
data_path = Path('text_docs/')
for d in data_path.glob("*.pdf"):
    try:
        loader = PyMuPDFLoader(str(d))
        docs.extend(loader.load())
        print(f"file loaded succesifuly: {d.name}")
    except Exception as e:
        print(f"failed to load the file {d.name}: {e}")
# Out:
# C:\Users\mmtor\AppData\Local\Temp\ipykernel_18260\515205958.py:2: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import PyMuPDFLoader
# file loaded succesifuly: Política de Reembolsos (Viagens e Despesas).pdf
# file loaded succesifuly: Política de Uso de E-mail e Segurança da Informação.pdf
# file loaded succesifuly: Políticas de Home Office.pdf

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

splitter = RecursiveCharacterTextSplitter(chunk_size=300, chunk_overlap=30)

chunks = splitter.split_documents(docs)

# %%
from langchain_google_genai import GoogleGenerativeAIEmbeddings, ChatGoogleGenerativeAI

embeddings = GoogleGenerativeAIEmbeddings(
    model = "models/gemini-embedding-001",
    google_api_key=GOOGLE_API_KEY
)

# %%
from langchain_community.vectorstores import FAISS

vectorstore = FAISS.from_documents(chunks, embeddings)
retriever = vectorstore.as_retriever(search_type= 'similarity_score_threshold',
                                     search_kwargs = {'score_threshold':0.3,'k':4})

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_classic.chains.combine_documents import create_stuff_documents_chain

rag_prompt = ChatPromptTemplate.from_messages([
    ("system", "You are an expert HR and IT assistant for the company 'Torres Devs'. "
               "Your main task is to answer employee questions based ONLY on the context provided. "
               "Be polite and professional in your responses. "
               "If the information to answer the question is not in the provided context, "
               "clearly state that you cannot find the answer in the company's documents."),
    
    ("user", "Based on our company's policies, please answer the following question:\n\nQuestion: {input}\n\nContext:\n{context}")
])

document_chain = create_stuff_documents_chain(llm, rag_prompt)

# %%
def ask_question_rag(question:str) -> dict:
    related_docs = retriever.invoke(question)

    if not related_docs:
        return {"answer": "cannot find the answer in the company's documents",
                "citations":[],
                "context_found": False}
    
    answer = document_chain.invoke({"input": question,
                                    "context": related_docs})
    text = (answer or "").strip()

    if text.rstrip(".!?") == "cannot find the answer in the company's documents":
        return {"answer": "cannot find the answer in the company's documents",
                "citations":[],
                "context_found": False}
    return {"answer": text,
            "citations":related_docs,
            "context_found": True}

# %% [markdown]
# CODIGO DA AULA

# %%
from typing import TypedDict, Optional, List

class AgentState(TypedDict, total = False):
    question: str
    triage: dict
    answer: Optional[str]
    citations: List[dict]
    rag_success: bool
    final_action: str

# %%
def triage_node(state: AgentState) -> AgentState:
    print("Executing the triaging node...")
    return {"triage": triage(state["question"])}

# %%
def self_resolve_node(state: AgentState) -> AgentState:
    print("Executing the self resolve node...")
    rag_answer = ask_question_rag(state["question"])

    update: AgentState = {"answer": rag_answer["answer"],
                          "citations": rag_answer.get("citations", []),
                          "rag_success": rag_answer["context_found"]}

    if rag_answer["context_found"]:
        update['final_action'] = "SELF_RESOLVE"

    return update

# %%
def request_info_node(state: AgentState) -> AgentState:
    print("Executing the ask for info node...")
    missing = state['triage'].get('missing_fields', [])
    detail = ",".join(missing) if missing else "tema e contexto específico"
    return {
        "answer": f"To move forward, I need you to provide this details: {detail}",
        "citations": [],
        "final_action": "REQUEST_INFO"}

# %%
def open_ticket_node(state: AgentState) -> AgentState:
    print("Executing the open ticket node...")
    return {
        "answer": f"I'm going to open a ticket for you with urgency {state['triage']['urgency']}. Descrição: {state["question"][:140]}",
        "citations": [],
        "final_action": "OPEN_TICKET"
    }

# %%
kw_open_ticket = ["exception","special case","outside of the policy","exceptional cost","approval","approve",
                  "authorization","authorize","manager to approve","budget","quote","release","clearance","unblock",
                  "access","permit","allow","open a ticket","create a ticket","log a request","file a ticket",
                  "formalize this request"]

# %%
def manager_triage(state: AgentState) -> str:
    print('deciding after the triage...')
    decision = state["triage"]["decision"]

    if decision == "SELF_RESOLVE": return "self"
    if decision == "REQUEST_INFO": return "request"
    if decision == "OPEN_TICKET": return "open"

# %%
def manager_self_resolve(state: AgentState) -> str:
    print('deciding after self resolve...')

    if state.get("rag_success"):
        print("RAG executed with success, ending the program") 
        return "end"
    
    question_state = (state["question"] or "").lower()

    if any(k in question_state for k in kw_open_ticket):
        print("RAG failed but i found a ticket key word. Opening a ticket...")
        return "open"
    
    print("RAG failed, I'm going to ask for more information")
    return "request"

# %%
from langgraph.graph import StateGraph, START, END

workflow = StateGraph(AgentState)

workflow.add_node("triage", triage_node)
workflow.add_node("self_resolve", self_resolve_node)
workflow.add_node("open_ticket", open_ticket_node)
workflow.add_node("request_info", request_info_node)

workflow.add_edge(START, "triage")
workflow.add_conditional_edges("triage", manager_triage, {
    "self": "self_resolve",
    "request": "request_info",
    "open": "open_ticket"
})
workflow.add_conditional_edges("self_resolve", manager_self_resolve, {
    "request": "request_info",
    "open": "open_ticket",
    "end": END
})

workflow.add_edge("request_info", END)
workflow.add_edge("open_ticket", END)

graph = workflow.compile()

# %%
from IPython.display import display, Image

graph_bytes = graph.get_graph().draw_mermaid_png()
display(Image(graph_bytes))

# %%
test_questions = [
    "How does the reimbursement policy for home office internet expenses work?",
    "I need to know the meal allowance rules for a trip next week; my flight is on Monday.",
    "I received an email that looks like phishing and I clicked the link. What does the security policy say I should do now?",
    "I have a question about a policy.",
    "I would like to request an exception to work 5 days a week remotely next month.",
    "Please open a ticket with HR to formalize my request for a course reimbursement."
]

# %%
for qst in test_questions:
    f_answer = graph.invoke({"question": qst})

    triag = f_answer.get("triage", {})
    print(f"Question: {qst}")
    print(f"Decision: {triag.get('decision')} | Urgency: {triag.get('urgency')} | Final action: {f_answer.get('final_action')}")
    print(f"Answer: {f_answer.get('answer')}")
    print()
    print("------------------------------------")
    print()
# Out:
# Executing the triaging node...
# deciding after the triage...
# Executing the self resolve node...
# deciding after self resolve...
# RAG executed with success, ending the program
# Question: How does the reimbursement policy for home office internet expenses work?
# Decision: SELF_RESOLVE | Urgency: LOW | Final action: SELF_RESOLVE
# Answer: Prezado(a) colaborador(a),
#
# De acordo com as políticas da Torres Devs, o reembolso para despesas de internet em regime de home office funciona da seguinte forma:
#
# *   Há um subsídio mensal de internet domiciliar de até R$ 100.
# *   Este subsídio é reembolsável mediante a apresentação de uma nota fiscal nominal.
#
# Atenciosamente,
#
# Equipe Torres Devs
#
# ------------------------------------
#
# Executing the triaging node...
# deciding after the triage...
# Executing the self resolve node...
# deciding after self resolve...
# RAG executed with success, ending the program
# Question: I need to know the meal allowance rules for a trip next week; my flight is on Monday.
# Decision: SELF_RESOLVE | Urgency: MEDIUM | Final action: SELF_RESOLVE
# Answer: Olá!
#
# Com base nas políticas da Torres Devs, para alimentação em viagem, o limite é de R$ 70 por dia por pessoa. É importante notar que bebidas alcoólicas não são reembolsáveis.
#
# Se precisar de mais alguma informação, por favor, me avise.
#
# ------------------------------------
#
# Executing the triaging node...
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# File c:\programming\Learning-agentic-AI\.venv\Lib\site-packages\langchain_google_genai\chat_models.py:3166, in ChatGoogleGenerativeAI._generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    3165 try:
# -> 3166     response: GenerateContentResponse = self.client.models.generate_content(
#    3167         **request,
#    3168     )
#    3169 except ClientError as e:
#
# File c:\programming\Learning-agentic-AI\.venv\Lib\site-packages\google\genai\models.py:6331, in Models.generate_content(self, model, contents, config)
#    6330 i += 1
# -> 6331 response = self._generate_content(
#    6332     model=model, contents=contents, config=parsed_config
#    6333 )
#    6335 function_map = _extra_utils.get_function_map(parsed_config)
#
# File c:\programming\Learning-agentic-AI\.venv\Lib\site-packages\google\genai\models.py:4767, in Models._generate_content(self, model, contents, config)
#    4765 request_dict = _common.encode_unserializable_types(request_dict)
# -> 4767 response = self._api_client.request(
#    4768     'post', path, request_dict, http_options
#    4769 )
#    4771 if config is not None and getattr(
#    4772     config, 'should_return_http_response', None
#    4773 ):
#
# File c:\programming\Learning-agentic-AI\.venv\Lib\site-packages\google\genai\_api_client.py:1605, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#    1602 http_request = self._build_request(
#    1603     http_method, path, request_dict, http_options
#    1604 )
# -> 1605 response = self._request(http_request, http_options, stream=False)
#    1606 response_body = (
#    1607     response.response_stream[0] if response.response_stream else ''
#    1608 )
#
# File c:\programming\Learning-agentic-AI\.venv\Lib\site-packages\google\genai\_api_client.py:1396, in BaseApiClient._request(self, http_request, http_options, stream)
#    1395     retry = tenacity.Retrying(**retry_kwargs)
# -> 1396     return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
#    1398 return self._retry(self._request_once, http_request, stream)
#
# File c:\programming\Learning-agentic-AI\.venv\Lib\site-packages\tenacity\__init__.py:470, in Retrying.__call__(self, fn, *args, **kwargs)
#     469 while True:
# --> 470     do = self.iter(retry_state=retry_state)
#     471     if isinstance(do, DoAttempt):
#
# File c:\programming\Learning-agentic-AI\.venv\Lib\site-packages\tenacity\__init__.py:371, in BaseRetrying.iter(self, retry_state)
#     370 for action in self.iter_state.actions:
# --> 371     result = action(retry_state)
#     372 return result
#
# File c:\programming\Learning-agentic-AI\.venv\Lib\site-packages\tenacity\__init__.py:413, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     412 if self.reraise:
# --> 413     raise retry_exc.reraise()
#     414 raise retry_exc from fut.exception()
#
# File c:\programming\Learning-agentic-AI\.venv\Lib\site-packages\tenacity\__init__.py:184, in RetryError.reraise(self)
#     183 if self.last_attempt.failed:
# --> 184     raise self.last_attempt.result()
#     185 raise self
#
# File ~\AppData\Roaming\uv\python\cpython-3.12.12-windows-x86_64-none\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#
# File ~\AppData\Roaming\uv\python\cpython-3.12.12-windows-x86_64-none\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     400 try:
# --> 401     raise self._exception
#     402 finally:
#     403     # Break a reference cycle with the exception in self._exception
#
# File c:\programming\Learning-agentic-AI\.venv\Lib\site-packages\tenacity\__init__.py:473, in Retrying.__call__(self, fn, *args, **kwargs)
#     472 try:
# --> 473     result = fn(*args, **kwargs)
#     474 except BaseException:  # noqa: B902
#
# File c:\programming\Learning-agentic-AI\.venv\Lib\site-packages\google\genai\_api_client.py:1375, in BaseApiClient._request_once(self, http_request, stream)
#    1374   response = self._httpx_client.send(httpx_request, stream=stream)  # type: ignore[union-attr]
# -> 1375 errors.APIError.raise_for_response(response)
#    1376 return HttpResponse(
#    1377     response.headers, response if stream else [response.text]
#    1378 )
#
# File c:\programming\Learning-agentic-AI\.venv\Lib\site-packages\google\genai\errors.py:155, in APIError.raise_for_response(cls, response)
#     153   response_json = response.body_segments[0].get('error', {})
# --> 155 cls.raise_error(response.status_code, response_json, response)
#
# File c:\programming\Learning-agentic-AI\.venv\Lib\site-packages\google\genai\errors.py:184, in APIError.raise_error(cls, status_code, response_json, response)
#     183 if 400 <= status_code < 500:
# --> 184   raise ClientError(status_code, response_json, response)
#     185 elif 500 <= status_code < 600:
#
# ClientError: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 5, model: gemini-2.5-flash\nPlease retry in 37.761248456s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash'}, 'quotaValue': '5'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '37s'}]}}
#
# The above exception was the direct cause of the following exception:
#
# ChatGoogleGenerativeAIError               Traceback (most recent call last)
# Cell In[24], line 2
#       1 for qst in test_questions:
# ----> 2     f_answer = graph.invoke({"question": qst})
#       3
#       4     triag = f_answer.get("triage", {})
#       5     print(f"Question: {qst}")
#
# File c:\programming\Learning-agentic-AI\.venv\Lib\site-packages\langgraph\pregel\main.py:3880, in Pregel.invoke(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, control, version, **kwargs)
#    3877             chunks.append(chunk)
#    3878 else:
#    3879     # v1: collect interrupts from updates stream
# -> 3880     for chunk in self.stream(
#    3881         input,
#    3882         config,
#    3883         context=context,
#    3884         stream_mode=(
#    3885             ["updates", "values"] if stream_mode == "values" else stream_mode
#    3886         ),
#    3887         print_mode=print_mode,
#    3888         output_keys=output_keys,
#    3889         interrupt_before=interrupt_before,
#    3890         interrupt_after=interrupt_after,
#    3891         durability=durability,
#    3892         control=control,
#    3893         **kwargs,
#    3894     ):
#    3895         if stream_mode == "values":
#    3896             if len(chunk) == 2:
#
# File c:\programming\Learning-agentic-AI\.venv\Lib\site-packages\langgraph\pregel\main.py:2936, in Pregel.stream(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, control, subgraphs, debug, version, **kwargs)
#    2934 for task in loop.match_cached_writes():
#    2935     loop.output_writes(task.id, task.writes, cached=True)
# -> 2936 for _ in runner.tick(
#    2937     [t for t in loop.tasks.values() if not t.writes],
#    2938     timeout=self.step_timeout,
#    2939     get_waiter=get_waiter,
#    2940     schedule_task=loop.accept_push,
#    2941 ):
#    2942     # emit output
#    2943     yield from _output(
#    2944         stream_mode,
#    2945         print_mode,
#    (...)   2951         _state_mapper,
#    2952     )
#    2953 loop.after_tick()
#
# File c:\programming\Learning-agentic-AI\.venv\Lib\site-packages\langgraph\pregel\_runner.py:207, in PregelRunner.tick(self, tasks, reraise, timeout, retry_policy, get_waiter, schedule_task)
#     205 scheduled_error_handler = False
#     206 try:
# --> 207     run_with_retry(
#     208         t,
#     209         retry_policy,
#     210         configurable={
#     211             CONFIG_KEY_CALL: partial(
#     212                 _call,
#     213                 weakref.ref(t),
#     214                 retry_policy=retry_policy,
#     215                 futures=weakref.ref(futures),
#     216                 schedule_task=schedule_task,
#     217                 submit=self.submit,
#     218             ),
#     219         },
#     220     )
#     221     self.commit(t, None)
#     222 except Exception as exc:
#
# File c:\programming\Learning-agentic-AI\.venv\Lib\site-packages\langgraph\pregel\_retry.py:585, in run_with_retry(task, retry_policy, configurable)
#     583     task.writes.clear()
#     584     # run the task
# --> 585     return task.proc.invoke(task.input, config)
#     586 except ParentCommand as exc:
#     587     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File c:\programming\Learning-agentic-AI\.venv\Lib\site-packages\langgraph\_internal\_runnable.py:684, in RunnableSeq.invoke(self, input, config, **kwargs)
#     682     # run in context
#     683     with set_config_context(config, run) as context:
# --> 684         input = context.run(step.invoke, input, config, **kwargs)
#     685 else:
#     686     input = step.invoke(input, config)
#
# File c:\programming\Learning-agentic-AI\.venv\Lib\site-packages\langgraph\_internal\_runnable.py:426, in RunnableCallable.invoke(self, input, config, **kwargs)
#     424         run_manager.on_chain_end(ret)
#     425 else:
# --> 426     ret = self.func(*args, **kwargs)
#     427 if self.recurse and isinstance(ret, Runnable):
#     428     return ret.invoke(input, config)
#
# Cell In[14], line 3, in triage_node(state)
#       1 def triage_node(state: AgentState) -> AgentState:
#       2     print("Executing the triaging node...")
# ----> 3     return {"triage": triage(state["question"])}
#
# Cell In[5], line 6, in triage(message)
#       5 def triage(message:str) ->dict:
# ----> 6     output: TriageOut = triage_chain.invoke([
#       7         SystemMessage(content=triage_Prompt),
#       8         HumanMessage(content=message)
#       9     ])
#
# File c:\programming\Learning-agentic-AI\.venv\Lib\site-packages\langchain_core\runnables\base.py:3333, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3331 with set_config_context(config) as context:
#    3332     if i == 0:
# -> 3333         input_ = context.run(step.invoke, input_, config, **kwargs)
#    3334     else:
#    3335         input_ = context.run(step.invoke, input_, config)
#
# File c:\programming\Learning-agentic-AI\.venv\Lib\site-packages\langchain_core\runnables\base.py:5881, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5874 @override
#    5875 def invoke(
#    5876     self,
#    (...)   5879     **kwargs: Any | None,
#    5880 ) -> Output:
# -> 5881     return self.bound.invoke(
#    5882         input,
#    5883         self._merge_configs(config),
#    5884         **{**self.kwargs, **kwargs},
#    5885     )
#
# File c:\programming\Learning-agentic-AI\.venv\Lib\site-packages\langchain_google_genai\chat_models.py:2644, in ChatGoogleGenerativeAI.invoke(self, input, config, code_execution, stop, **kwargs)
#    2641         msg = "Tools are already defined.code_execution tool can't be defined"
#    2642         raise ValueError(msg)
# -> 2644 return super().invoke(input, config, stop=stop, **kwargs)
#
# File c:\programming\Learning-agentic-AI\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:474, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     460 @override
#     461 def invoke(
#     462     self,
#    (...)    467     **kwargs: Any,
#     468 ) -> AIMessage:
#     469     config = ensure_config(config)
#     470     return cast(
#     471         "AIMessage",
#     472         cast(
#     473             "ChatGeneration",
# --> 474             self.generate_prompt(
#     475                 [self._convert_input(input)],
#     476                 stop=stop,
#     477                 callbacks=config.get("callbacks"),
#     478                 tags=config.get("tags"),
#     479                 metadata=config.get("metadata"),
#     480                 run_name=config.get("run_name"),
#     481                 run_id=config.pop("run_id", None),
#     482                 **kwargs,
#     483             ).generations[0][0],
#     484         ).message,
#     485     )
#
# File c:\programming\Learning-agentic-AI\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1823, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1814 @override
#    1815 def generate_prompt(
#    1816     self,
#    (...)   1820     **kwargs: Any,
#    1821 ) -> LLMResult:
#    1822     prompt_messages = [p.to_messages() for p in prompts]
# -> 1823     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File c:\programming\Learning-agentic-AI\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1630, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1627 for i, m in enumerate(input_messages):
#    1628     try:
#    1629         results.append(
# -> 1630             self._generate_with_cache(
#    1631                 m,
#    1632                 stop=stop,
#    1633                 run_manager=run_managers[i] if run_managers else None,
#    1634                 **kwargs,
#    1635             )
#    1636         )
#    1637     except BaseException as e:
#    1638         if run_managers:
#
# File c:\programming\Learning-agentic-AI\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1970, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1968     result = generate_from_stream(iter(chunks))
#    1969 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1970     result = self._generate(
#    1971         messages, stop=stop, run_manager=run_manager, **kwargs
#    1972     )
#    1973 else:
#    1974     result = self._generate(messages, stop=stop, **kwargs)
#
# File c:\programming\Learning-agentic-AI\.venv\Lib\site-packages\langchain_google_genai\chat_models.py:3170, in ChatGoogleGenerativeAI._generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    3166     response: GenerateContentResponse = self.client.models.generate_content(
#    3167         **request,
#    3168     )
#    3169 except ClientError as e:
# -> 3170     _handle_client_error(e, request)
#    3172 return _response_to_result(response)
#
# File c:\programming\Learning-agentic-AI\.venv\Lib\site-packages\langchain_google_genai\chat_models.py:169, in _handle_client_error(e, request)
#     167 model_name = request.get("model", "unknown")
#     168 msg = f"Error calling model '{model_name}' ({e.status}): {e}"
# --> 169 raise ChatGoogleGenerativeAIError(msg) from e
#
# ChatGoogleGenerativeAIError: Error calling model 'gemini-2.5-flash' (RESOURCE_EXHAUSTED): 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 5, model: gemini-2.5-flash\nPlease retry in 37.761248456s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash'}, 'quotaValue': '5'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '37s'}]}}
# During task with name 'triage' and id '9be58d45-3696-528c-7d9b-c8931cedd130'
