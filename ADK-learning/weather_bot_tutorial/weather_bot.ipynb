# %%
import os
import asyncio
from google.adk.agents import Agent
from google.adk.sessions import InMemorySessionService
from google.adk.runners import Runner
from google.genai import types
from dotenv import load_dotenv

import warnings
warnings.filterwarnings("ignore")

import logging
logging.basicConfig(level=logging.ERROR)

load_dotenv()
GOOGLE_API_KEY = os.getenv("GOOGLE_API_KEY")

# %%
import torch

# 1. Check for basic CUDA availability
if torch.cuda.is_available():
    print("✅ PyTorch has successfully detected a CUDA-capable GPU!")
    
    # 2. Confirm the name matches what nvidia-smi showed
    detected_name = torch.cuda.get_device_name(0)
    print(f"   Detected GPU Name: {detected_name}")
    
    # 3. Show memory details (optional, but good for diagnostics)
    total_memory_gib = torch.cuda.get_device_properties(0).total_memory / (1024**3)
    print(f"   Total Memory (GiB): {total_memory_gib:.2f}")
    
    # 4. Critical: Ensure a tensor can be placed on the device
    test_tensor = torch.zeros(1).cuda()
    print(f"   Test tensor is on device: {test_tensor.device}")
else:
    print("❌ PyTorch is running on CPU. Check your environment/CUDA installation.")
    print("   (Ensure you installed the CUDA-enabled version of PyTorch, e.g., torch-cuda)")
# Out:
# ✅ PyTorch has successfully detected a CUDA-capable GPU!
#    Detected GPU Name: NVIDIA GeForce GTX 1650
#    Total Memory (GiB): 4.00
#    Test tensor is on device: cuda:0
